# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')
area=[]
for  i in df['鄉鎮市區'].drop_duplicates().values:
    area.append(i[:-1])
for j in df['縣市'].drop_duplicates().values:
    area.append(j)
    area.append(j[:-1])
print(len(area))
# Out:
# 376

# %%
df_1 = pd.read_csv('news_url_data1.csv')
df_2 = pd.read_csv('news_url_data2.csv')
df_3 = pd.read_csv('news_url_data3.csv')
df_4 = pd.read_csv('news_url_data4.csv')
df_5 = pd.read_csv('news_url_data5.csv')
df_6 = pd.read_csv('news_url_data6.csv')

# %%
for i in df_5.values:
    print(i[0].split(' ')[0])
# Out:
# 2020-05-01
# 2020-05-01
# 2020-05-01
# 2020-05-01
# 2020-05-01
# 2020-05-01
# 2020-05-01
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-02
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-03
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-04
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# 2020-05-05
# ...

# %%
df_t = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6], axis=0)

print(df_6)
# Out:
#      2020-06-01 00:00:00       公視新聞網  \
# 0    2020-06-01 01:23:00       三立新聞網
# 1    2020-06-01 01:30:56        奇摩新聞
# 2    2020-06-01 01:50:00       三立新聞網
# 3    2020-06-01 01:51:01     自由時報電子報
# 4    2020-06-01 01:55:55        奇摩新聞
# ..                   ...         ...
# 911  2020-06-30 17:20:38        奇摩新聞
# 912  2020-06-30 17:31:31        奇摩新聞
# 913  2020-06-30 17:37:00  LINE TODAY
# 914  2020-06-30 18:48:36     自由時報電子報
# 915  2020-06-30 22:23:13     自由時報電子報
#
#                                          ['雲林', '雲林縣']  \
# 0    ['基隆市', '七堵', '暖暖', '仁愛', '安樂', '信義', '台北市', '...
# 1    ['基隆市', '七堵', '暖暖', '仁愛', '安樂', '信義', '台北市', '...
# 2                                         ['台北', '信義']
# 3                                         ['台北', '仁愛']
# 4                                         ['台北', '信義']
# ..                                                 ...
# 911  ['台中市', '新北', '基隆', '新北市', '苗栗縣', '澎湖', '金門', ...
# 912                                             ['台南']
# ...

# %%
import numpy as np
area_num=[]
for i in df_1.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_2.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_3.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_4.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_5.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_6.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
            
areanum = pd.DataFrame(area_num,columns = ['time','area','num'])
area_gro = areanum.groupby(['time','area']).sum()

# %%
area_new=[]
for i,j in enumerate(area_gro.values):
    area_new.append([area_gro.index[i][0],area_gro.index[i][1],j[0]])
area_df = pd.DataFrame(area_new,columns = ['time','area','num'])
area_df
# Out:
#             time area  num
# 0     2020-01-01   基隆    8
# 1     2020-01-01   宜蘭    4
# 2     2020-01-01   恆春    4
# 3     2020-01-01   新竹    1
# 4     2020-01-01   桃園    1
# ...          ...  ...  ...
# 4053  2020-06-30   蘭嶼    2
# 4054  2020-06-30   金峰    1
# 4055  2020-06-30   金門    8
# 4056  2020-06-30   雲林   12
# 4057  2020-06-30   高雄    3
#
# [4058 rows x 3 columns]

# %%
rain_area=[]
for i in df.values:
    if i[1] == '高雄市' or i[1] == '屏東縣' :
        rain_area.append(i[2][:-1])
        rain_area.append(i[1][:-1])

rain_df = pd.DataFrame(rain_area).drop_duplicates()
rain_area=[]
for i in rain_df.values:
    rain_area.append(i[0])
print(rain_area)
# Out:
# ['前鎮', '高雄', '恆春', '屏東', '三地門', '霧臺', '瑪家', '內埔', '鹽埔', '萬巒', '潮州', '春日', '琉球', '滿州', '車城', '牡丹', '高樹', '長治', '九如', '萬丹', '崁頂', '林邊', '佳冬', '新埤', '新園', '麟洛', '南州', '里港', '泰武', '東港', '竹田', '枋寮', '枋山', '獅子', '來義', '桃源', '甲仙', '杉林', '美濃', '大樹', '內門', '田寮', '燕巢', '鳳山', '小港', '新興', '旗津', '阿蓮', '梓官', '永安', '茄萣', '湖內', '彌陀', '岡山', '楠梓', '仁武', '鼓山', '三民', '苓雅', '林園', '大寮', '旗山', '路竹', '橋頭', '大社', '茂林', '六龜', '左營', '那瑪夏']

# %%
df_dict = dict()
for i in area:
    df_dict[i] = area_df[area_df['area'] == i]
df_dict
# Out:
# {'板橋':             time area  num
#  1191  2020-03-13   板橋    2
#  2188  2020-05-11   板橋    1
#  2327  2020-05-16   板橋    3
#  2370  2020-05-17   板橋    1
#  2441  2020-05-18   板橋    2
#  3733  2020-06-14   板橋    5
#  3760  2020-06-15   板橋    1
#  3879  2020-06-23   板橋    1
#  3936  2020-06-26   板橋    3,
#  '淡水':             time area  num
#  152   2020-01-13   淡水    5
#  268   2020-01-21   淡水    1
#  278   2020-01-22   淡水    1
#  386   2020-02-01   淡水    1
#  2915  2020-05-24   淡水    1
#  2960  2020-05-25   淡水    1
#  3386  2020-06-01   淡水    2
#  3736  2020-06-14   淡水    1,
#  '北投':             time area  num
#  1522  2020-04-01   北投    1
#  2413  2020-05-18   北投    2,
#  '中正':             time area  num
#  2403  2020-05-18   中正    2
#  2651  2020-05-22   中正    4
#  2897  2020-05-24   中正    1
#  3128  2020-05-28   中正    1
#  3473  2020-06-05   中正    1,
#  '仁愛':             time area  num
#  143   2020-01-13   仁愛    1
#  625   2020-02-13   仁愛    3
#  659   2020-02-14   仁愛    3
# ...

# %%
time = area_df['time'].drop_duplicates()

df_total =[]
for i in rain_area:
    for t in time.values:
        for y in df_dict[i].values:
            if t == y[0] :
                df_total.append(y)
            else:
                df_total.append([t,i,0])
df_total = pd.DataFrame(df_total,columns = ['time','area','num'])
df_total = df_total.drop_duplicates()

df_rain_dict = dict()
for i in rain_area:
    df_rain_dict[i] = df_total[df_total['area'] == i]
df_rain_dict
# Out:
# {'前鎮':            time area  num
#  0    2020-01-01   前鎮    0
#  4    2020-01-02   前鎮    0
#  8    2020-01-03   前鎮    0
#  12   2020-01-04   前鎮    0
#  16   2020-01-05   前鎮    0
#  ..          ...  ...  ...
#  704  2020-06-26   前鎮    0
#  708  2020-06-27   前鎮    0
#  712  2020-06-28   前鎮    0
#  716  2020-06-29   前鎮    0
#  720  2020-06-30   前鎮    0
#
#  [185 rows x 3 columns],
#  '高雄':              time area  num
#  724    2020-01-01   高雄    0
#  854    2020-01-02   高雄    0
#  984    2020-01-03   高雄    4
#  985    2020-01-03   高雄    0
#  1114   2020-01-04   高雄    0
#  ...           ...  ...  ...
#  23991  2020-06-28   高雄   19
#  23994  2020-06-29   高雄    0
#  24122  2020-06-29   高雄   12
#  24124  2020-06-30   高雄    0
#  24253  2020-06-30   高雄    3
#
#  [311 rows x 3 columns],
#  '恆春':              time area  num
#  24254  2020-01-01   恆春    4
#  24255  2020-01-01   恆春    0
#  24352  2020-01-02   恆春    0
#  24353  2020-01-02   恆春    3
#  24450  2020-01-03   恆春    0
# ...

# %%
for i in df_dict["苓雅"]
# Out:
#             time area  num
# 1494  2020-03-30   苓雅    1
# 2751  2020-05-22   苓雅    7
# 2870  2020-05-23   苓雅    1
# 2972  2020-05-25   苓雅    5
# 3105  2020-05-27   苓雅    2
# 3518  2020-06-06   苓雅    4

# %%
import numpy as np
area_num=[]
for i in df_1.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_2.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_3.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_4.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_5.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
for i in df_6.values:
    for j in i[2].strip('][').split(', '):
        new_area = j.replace("'","")
        if new_area[:2] in area:
            area_num.append([i[0].split(' ')[0],new_area[:2],1])
            
areanum = pd.DataFrame(area_num,columns = ['time','area','num'])
